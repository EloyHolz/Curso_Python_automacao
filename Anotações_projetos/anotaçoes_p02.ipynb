# %% [markdown]
# # Automatizar tarefas com Pyhon - projeto 02
#
#
# Passo a passo do problema ->
#     - Buscar as informações da ação auto
#     - Criar as análises solicitadas
#         - Cotação max e min
#         - valor médio
#     - Enviar um email auto para o gestor

# %% [markdown]
# #### Buscar info das açoes auto

# %%
import yfinance

# %%
ticker = input("Digite o Código da ação desejada: ")
dados = yfinance.Ticker(ticker).history(start="2020-01-01", end="2020-12-31")
fechamento = dados.Close
fechamento.plot()
valor_max = round(fechamento.max(), 2)
valor_medio = round(fechamento.mean(), 2)
valor_minimo = round(fechamento.min(), 2)

print (valor_max)
print(valor_medio)
print(valor_minimo)
# Out:
# 19.97
# 13.36
# 8.33

# %% [markdown]
# #### Criar as análises Solicitadas
#
#     - Cotação Máxima
#     - Cotação Mínima
#     - Valor médio

# %% [markdown]
# #### Enviar o email automaticamente
#
# - abrir o navegador e ir para o Gmail
# - clicar no botão escrever
# - digitar o email do destinatário e clicar tab
# - digiar o assunto do email e digitar tab
# - digitar a mensagem
# - clicar no botão de enviar

# %%
import pyautogui
import pyperclip
import webbrowser
import time

destinatario = "eloyneto61@gmail.com"
assunto = "Teste automação python"
mensagem = f"""
Prezado Gestor,

Seguem as análises da ação {ticker}:

Cotação máxíma: R${valor_max}
Cotação Minima: R$ {valor_minimo}
Valor Médio: R${valor_medio}

Qualquer duvida, estou à disposição

Atte.
"""

#texto com 3 aspas pode quebrar a linha

#abrir navegador e ir para o email
webbrowser.open("www.gmail.com")
time.sleep(4)

#Configurando pausa de 3s do pyautogui
pyautogui.PAUSE = 3

#Clicar no botao escrever
pyautogui.click(x=102, y=171)

#digitar o email o dest e clicar tab
pyperclip.copy(destinatario)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#digitar asssunto do email + tab
pyperclip.copy(assunto)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#digitar texto
pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", 'v')

#clicar no botao enviar
pyautogui.click (x=1296, y=1017)

# %%
#Pra identificar o ponto na tela que vai clicar
time.sleep(10)
pyautogui.position()
# Out:
# Point(x=1296, y=1017)
